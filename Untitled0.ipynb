# %% [markdown]
# <a href="https://colab.research.google.com/github/bep270324/colab/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Installazione texturize - prima connettersi e scegliere il supporto GPU T4 nel runtime

# %%
# !pip install texturize
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=66a6277ded7f130fef2cb405bf1bd1e3e954cc2c95919f303723aad3cdcde957
#   Stored in directory: /root/.cache/pip/wheels/fc/ab/d4/5da2067ac95b36618c629a5f93f809425700506f72c9732fac
# Successfully built docopt
# ...

# %%
from texturize import api, commands, io

BASE_URL = "https://github.com/photogeniq/texturize/releases/download/v0.0/"
# @title Settings

resolution = '0.6 MP'             # @param ['0.3 MP', '0.6 MP']
quality = 4                       # @param {type:"slider", min:0, max:10, step:1}

target_sizes = {
    '0.3 MP': (736, 352),
    '0.6 MP': (1088, 544),
}

source_crops = {
    '0.3 MP': (528, 528),
    '0.6 MP': (776, 776),
}


def synthesize(image):
    """An iterator that yields a new result each step of the optimation.
    """
    remix = commands.Remix(image)

    return api.process_iterations(
        remix,
        octaves=None,                    # Number of levels in coarse-to-fine rendering.
        size=target_sizes[resolution]  # Resolution of the output, must fit in GPU memory.
                         # The quality level, higher is better.
    )

# %%
gravel1 = io.load_image_from_url(BASE_URL + "gravel1.webp")  # Image CC-BY-NC-SA @alexjc.
gravel1 = io.random_crop(gravel1, source_crops[resolution])

io.show_image_as_tiles(gravel1, count=5, size=(144, 144))

# %%
display_widget = io.show_result_in_notebook()

for result in synthesize(gravel1):
    display_widget.update(result)
# Out:
# ...
# IntProgress(value=0, layout=Layout(margin='0', width='100%'))
